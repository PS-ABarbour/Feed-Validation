# %%
import pandas as pd
from difflib import SequenceMatcher
import numpy as np
import re

# %%
cvspath = 'data/PnG_Pampers_NL_Product_Feed_OG.csv'
tamppath = 'data/PnG_Pampers_NL_Product_Feed_OG.xlsx'

ccPath = 'data/country_codes.xlsx'
lcPath = 'data/lang_codes.xlsx'

sellerFeedPath = 'data/seller-feeds/ApexToolGroup_Store_Feed.xlsx'
productFeedPath = 'data/product-feeds/PnG_Pampers_AE_Product_Feed.xlsx'

# data = pd.read_excel(tamppath, converters={'SKU': lambda x: str(x)})
sfData = pd.read_excel(sellerFeedPath)
pfData = pd.read_excel(productFeedPath)

countryCodes = pd.read_excel(ccPath)
langCodes = pd.read_excel(lcPath)

sfData
# Out:
#      Country         sellerName sellerID                     storeName  \
# 0         CA  Acklands Grainger   100000  Acklands Grainger Inc - AC0
# 1         CA  Acklands Grainger   100000  Acklands Grainger Inc - AA9
# 2         CA  Acklands Grainger   100000  Acklands Grainger Inc - AC4
# 3         CA  Acklands Grainger   100000  Acklands Grainger Inc - AC1
# 4         CA  Acklands Grainger   100000  Acklands Grainger Inc - AC2
# ...      ...                ...      ...                           ...
# 8657      US          White Cap   110600      White Cap - Seattle - 46
# 8658      US          White Cap   110600      White Cap - Spokane - 47
# 8659      US          White Cap   110600      White Cap - Tacoma - 506
# 8660      US          White Cap   110600    White Cap - Cheyenne - 501
# 8661      US      Wylaco Supply   110700            Wylaco Supply - 00
#
#              storeID                            productGroup  sku  \
# 0               AC0                 US GearWrench | US Jobox  NaN
# 1               AA9                 US GearWrench | US Jobox  NaN
# 2               AC4                 US GearWrench | US Jobox  NaN
# 3               AC1                 US GearWrench | US Jobox  NaN
# 4               AC2                 US GearWrench | US Jobox  NaN
# ...              ...                                     ...  ...
# 8657    Seattle - 47  US Crescent | US GearWrench | US Jobox  NaN
# 8658    Spokane - 48  US Crescent | US GearWrench | US Jobox  NaN
# 8659    Tacoma - 507  US Crescent | US GearWrench | US Jobox  NaN
# 8660  Cheyenne - 502  US Crescent | US GearWrench | US Jobox  NaN
# 8661              00             US Crescent | US GearWrench  NaN
#
#                       address  address2        city  ...        Wednesday  \
# 0              3 Kingsview Rd       NaN     Airdrie  ...  8:00am - 5:00pm
# 1               5802 - 50 Ave       NaN  Bonnyville  ...  7:00am - 5:00pm
# 2     3401 - 19 St NE Bay #10       NaN     Calgary  ...  7:00am - 5:00pm
# 3        4340 Manhattan Rd SE       NaN     Calgary  ...  7:00am - 5:00pm
# 4            4949 - 61 Ave SE       NaN     Calgary  ...  7:00am - 5:00pm
# ...                       ...       ...         ...  ...              ...
# 8657        4121 - 6th Ave NW       NaN     Seattle  ...  7:00am - 4:30pm
# 8658         3825 E Trent Ave       NaN     Spokane  ...  7:00am - 4:30pm
# 8659           3037 Center St       NaN      Tacoma  ...  7:00am - 4:30pm
# 8660            3957 W 5th St       NaN    Cheyenne  ...  7:00am - 4:30pm
# 8661           315 Vallejo St       NaN      Denver  ...  7:30am - 5:00pm
#
#              Thursday           Friday          Saturday  Sunday   latitude  \
# 0     8:00am - 5:00pm  8:00am - 5:00pm               NaN     NaN  51.083163
# 1     7:00am - 5:00pm  7:00am - 5:00pm               NaN     NaN  55.278487
# 2     7:00am - 5:00pm  7:00am - 5:00pm               NaN     NaN  42.931627
# 3     7:00am - 5:00pm  7:00am - 5:00pm               NaN     NaN  51.014805
# 4     7:00am - 5:00pm  7:00am - 5:00pm               NaN     NaN  50.998624
# ...               ...              ...               ...     ...        ...
# 8657  7:00am - 4:30pm  7:00am - 4:30pm            Closed  Closed  47.657372
# 8658  7:00am - 4:30pm  7:00am - 4:30pm            Closed  Closed  32.277534
# 8659  7:00am - 4:30pm  7:00am - 4:30pm            Closed  Closed  41.220287
# 8660  7:00am - 4:30pm  7:00am - 4:30pm            Closed  Closed  41.116547
# 8661  7:30am - 5:00pm  7:30am - 5:00pm  8:00am - 12:00pm  closed  39.698343
#
#      longitude                                 sellerUrl sellerUrlLabel  \
# 0     -114.012                                       NaN            NaN
# 1     -114.773                                       NaN            NaN
# 2     -81.2125                                       NaN            NaN
# 3     -114.052                                       NaN            NaN
# 4     -113.963                                       NaN            NaN
# ...        ...                                       ...            ...
# 8657  -122.364  https://www.whitecap.com/shop/en/wc/home    See Website
# 8658  -111.019  https://www.whitecap.com/shop/en/wc/home    See Website
# 8659  -112.023  https://www.whitecap.com/shop/en/wc/home    See Website
# 8660  -104.848  https://www.whitecap.com/shop/en/wc/home    See Website
# 8661  -105.003                   https://www.wylaco.com/    See Website
#
#      miscText
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 8657      NaN
# 8658      NaN
# 8659      NaN
# 8660      NaN
# 8661      NaN
#
# [8662 rows x 25 columns]

# %%
# removes whitespace
def remove_whitespace(df):
    dataDict = df.to_dict('records')
    for x in dataDict:
        for value in x:
            try:
                x[value] = " ".join(x[value].split())

            except:
#               passes on ints
                pass
    data = pd.DataFrame.from_dict(dataDict)
    return data

# %%
# verifies upc is numeric and is 13-15 digits lon. Takes in df and upc column name.
def upc_validation(df,upcColumnName):
    badUPCs = []
    dataDict = df.to_dict('records')
    for x in dataDict:
        upcLen = len(str(x[upcColumnName]))
#       append non numerical upc's to badUPCs
        try:
            x[upcColumnName] = int(float(x[upcColumnName]))
        except:
            badUPCs.append(x)
#       verify length of upc
        if upcLen < 13 or upcLen > 15:
            if x not in badUPCs:
                badUPCs.append(x)
            else:
                pass
        else:
            pass
        
#   remove upc's with nan or empty values. Since value is alound to be empty
    for item in badUPCs[:]:
        strUpc = str(item[upcColumnName])
        if strUpc == "nan" or strUpc == "":
            badUPCs.remove(item)
        else:
            pass
        
    for x in badUPCs:
        if x in dataDict[:]:
            dataDict.remove(x)
#                 print(x)
        else:
            pass
        
        dfGood = pd.DataFrame(dataDict)
        dfBad =  pd.DataFrame(badUPCs)  
        
    return dfGood, dfBad

df1, dfBadUPC = upc_validation(data,"upc")
# print(dfBadUPC.to_string(),df1.to_string())
dfBadUPC
# Out:
#   Country manufacturerName            sku  altSku                       model  \
# 0      NL          Pampers  4015400833826     NaN  NL LUIERS Pampers Baby-Dry
# 1      NL          Pampers  4015400833857     NaN  NL LUIERS Pampers Baby-Dry
# 2      NL          Pampers  4015400834168     NaN  NL LUIERS Pampers Baby-Dry
# 3      NL          Pampers  4015400566748     NaN  NL LUIERS Pampers Baby-Dry
# 4      NL          Pampers  4015400833918     NaN  NL LUIERS Pampers Baby-Dry
#
#                productName               upc  releaseDate  \
# 0  LUIERS Pampers Baby-Dry           Pampers          NaN
# 1  LUIERS Pampers Baby-Dry        4000000010          NaN
# 2  LUIERS Pampers Baby-Dry       40000000011          NaN
# 3  LUIERS Pampers Baby-Dry      400000000012          NaN
# 4  LUIERS Pampers Baby-Dry  4000000000000160          NaN
#
#                                       productPageUrl  \
# 0  https://www.pampers.nl/producten/pampers-baby-dry
# 1  https://www.pampers.nl/producten/pampers-baby-dry
# 2  https://www.pampers.nl/producten/pampers-baby-dry
# 3  https://www.pampers.nl/producten/pampers-baby-dry
# 4  https://www.pampers.nl/producten/pampers-baby-dry
#
#                                             imageUrl productGroup category  \
# 0  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 1  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 2  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 3  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 4  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
#
#     productCategory       productType                                  size  \
# 0  pampers-baby-dry    Maat 4 9/14 kg   86  luiers (voor ongeveer 20 dagen)
# 1  pampers-baby-dry    Maat 4 9/14 kg   96  luiers (voor ongeveer 22 dagen)
# 2  pampers-baby-dry  Maat 4+ 10/15 kg  112  luiers (voor ongeveer 25 dagen)
# 3  pampers-baby-dry  Maat 4+ 10/15 kg  152  luiers (voor ongeveer 34 dagen)
# 4  pampers-baby-dry  Maat 4+ 10/15 kg    24  luiers (voor ongeveer 6 dagen)
#
#   resourceLanguage  Column17  Column18
# 0               ES       NaN       NaN
# 1               ES       NaN       NaN
# 2               ES       NaN       NaN
# 3               ES       NaN       NaN
# 4               ES       NaN       NaN

# %%
# takes in a list of good brands and a list of questionable brands and spits out a Dict of brands to replace
def comparison_swap(good, questionable):
    
    gthreshold = []
    qthreshold = [] 
    ratioDict = []

    
#   Creates two lists of the same len that are aligned via index based on character similarity.
    for g in list(good):
        for q in questionable:
            ratiothresh = SequenceMatcher(None, g, q).ratio()
            if ratiothresh > 0.50:
                gthreshold.append(g)
                qthreshold.append(q)
            else:
                pass
#     print(gthreshold,qthreshold,"\n")

#   Send to lowercasee for case insensitive comparison
    gL = (word.lower() for word in gthreshold)
    qL = (word.lower() for word in qthreshold)
    
#   loop grab ratio of each pair and change if necessary
    for index, (wordg, wordq) in enumerate(zip(gL,qL)):
#       check if values are the same before attempting the switch
        if qthreshold[index] is gthreshold[index]:
            same = True
        else:
            same = False
        
        ratio = SequenceMatcher(None, wordg, wordq).ratio()
        
#       switch the questionable brand to the good brand
        if ratio > 0.80 and same == False:
            replaced = qthreshold[index]
            qthreshold[index] = gthreshold[index]
        else:
            replaced = "N/A"
            
            
        ratioDict.append({
            "ratio": ratio, 
            "examined": gthreshold[index],
            "replaced": replaced,
            "with": qthreshold[index]})
    
    return ratioDict

# %%
# finds brands that have a low count and attempts to update them based on similar barnd switch. 
def outlier_detect(df,brandColumnName):

    dataDict = df.to_dict('records')
    q_brands = []
    g_brands = []
    brandDict = []
    
#   count frequency of brands
    brandCounts = df[brandColumnName].value_counts()
    
#   determine cut off as a perct of mean
    mean = np.mean(brandCounts)
    cut_off = 0.10 * mean
    

#   append brand names to q_brand that appear less than the cutoff.
    for key, value in brandCounts.items():
        if value < cut_off:
            q_brands.append(key)
        else:
            g_brands.append(key)
            
#   See similar_brand_switch       
    flagged_brands = comparison_swap(g_brands, q_brands)
    
#   create list of rows that contain the question brand names.
    for x in dataDict:
        if x[brandColumnName] in q_brands:
            brandDict.append(x)
            
#   Replace brands in dataDict that have been id'd in flagged_brands for replacement
    for y in brandDict:
        for z in flagged_brands:
            if y[brandColumnName] == z["replaced"]:         
                y[brandColumnName] = z["with"]
                
    
    branddf = pd.DataFrame(dataDict) 
    
#   get value counts again. Send any stragglers to error df
    brandCounts2 = branddf[brandColumnName].value_counts()
    
    lowCountIndex = []
    
    for key, value in brandCounts2.items():
        if value < 2:
            indx = branddf.index[branddf[brandColumnName] == key].tolist()
            lowCountIndex.append(indx)  

#   flatten lowCountIndex that comes back as a 1x2 list
    flatList = []
    
    for sublist in lowCountIndex:
        for indx in sublist:
            flatList.append(indx)
            
    uncorrected = branddf.iloc[flatList]
    
    branddf = branddf.drop(flatList)
    
    return branddf, uncorrected
        
good, bad = outlier_detect(data, "manufacturerName")
bad
# Out:
#     Country manufacturerName            sku altSku  \
# 185      NL         Salmmers  8001090834966    NaN
#
#                           model              productName            upc  \
# 185  NL Pampers Pure Protection  Pampers Pure Protection  8001090834966
#
#     releaseDate                                     productPageUrl  \
# 185         NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
#
#                                               imageUrl productGroup category  \
# 185  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
#
#                     productCategory productType                          size  \
# 185  pampers-pure-protection-luiers           5  24 luiers (voor +/- 6 dagen)
#
#     resourceLanguage Column17  Column18
# 185               en      NaN       NaN

# %%
# finds duplicate skus,altskus, or upc against country or lang. Accepts dataframe and column name as string
def dup_validation(df,dupColumnaName,againstColumnName,*columns):
    dataDict = df.to_dict('records')
    
    colNameList = [dupColumnaName, againstColumnName]
    
#   adds optional args to colNameList
    for col in columns:
        colNameList.append(col)
    
    print(colNameList)
    
#   duplicated returns second instance of value as pd.series
    dup = df.duplicated(colNameList)
    
#   list of indexes to use in loc
    indexList = []
    
#   iterate through boolean duplicate data to return indexs of dups
    for key, value in dup.items():
        if value == True:
            indexList.append(key)
            
    dfClean = df.drop(df.index[indexList])
    
#   df of dups pulled by in dup
    dupDF = df.iloc[indexList]
    
    
######################################################################################################################
# logic to remove all instaces of dups. 

# #   Send df sku column to list
#     sku_list = rows[dupColumnaName].tolist()
    
#     dupList = []
    
# #   find the dup and the original from df and append to list
#     for x in dataDict:
#         if x[dupColumnaName] in sku_list:
#             dupList.append(x)


#     dfBad =  pd.DataFrame(dupList) 
######################################################################################################################

            
    
    dfGood = dfClean
    dfBad = dupDF

                
    return dfGood, dfBad
    
df2, dfDup = dup_validation(sfData, "sellerID", "sellerName", "storeName", "storeID")   

dfDup
# Out:
# ['sellerID', 'sellerName', 'storeName', 'storeID']
#   Country                        sellerName  sellerID  storeName  storeID  \
# 1      US  2Guyz Boutique for Dogs and Cats      1926        NaN      NaN
#
#     productGroup           address         address2    city state    zip  \
# 1  All Products   1453 South A St.  Suites 1000 A-D  Elwood    IN  46036
#
#             phone                   Website
# 1  (765) 356-7387  http://elwoodpetshop.com

# %%
# wont work on two word categorys
# pipes altskus and categorys. Takes in df and column name you want to pipe. 
def pipe_it(df,columnNametoPipe):
    
    dataDict = df.to_dict('records')
    
#   splits on non word characters and joins with |
    for x in dataDict:
        pipeStr = str(x[columnNametoPipe])
        regexList = re.split(r"\W+(?<!-)(?<!\s)\s*", pipeStr)
        x[columnNametoPipe] = "|".join(regexList)
        
    asDf = pd.DataFrame(dataDict)

    return asDf

pipeDF = pipe_it(data,"altSku")
pipeDF
# Out:
#     Country manufacturerName            sku                   altSku  \
# 0        nl           Pamper  4015400833079          1|420blazit|wow
# 1        NL          Pamperz  8001090268617          1asdf|asdf|pipe
# 2        GE          pampers  4015400833154  this is made of altskus
# 3        US          Pampers  4015400833154        4015400833154|hat
# 4        NL          Pampers  8001090268617             1234|232|234
# ..      ...              ...            ...                      ...
# 183      NL          Pampers  8001090834904                      nan
# 184      NL          Pampers  8001841115979                      nan
# 185      NL          Pampers  8001090834966                      nan
# 186      NL          Pampers  8001841023335                      nan
# 187      NL          Pampers  8001841116037                      nan
#
#                           model              productName            upc  \
# 0    NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  4015400833079
# 1    NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  8001090088185
# 2    NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  8001090336354
# 3    NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  4015400833154
# 4    NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  4015400833420
# ..                          ...                      ...            ...
# 183  NL Pampers Pure Protection  Pampers Pure Protection  8001090834904
# 184  NL Pampers Pure Protection  Pampers Pure Protection  8001841115979
# 185  NL Pampers Pure Protection  Pampers Pure Protection  8001090834966
# 186  NL Pampers Pure Protection  Pampers Pure Protection  8001841023335
# 187  NL Pampers Pure Protection  Pampers Pure Protection  8001841116037
#
#              releaseDate                                     productPageUrl  \
# 0    2019-07-20 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# 1    2019-07-21 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# 2    2019-07-22 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# 3    2019-07-23 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# 4    2019-07-12 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# ..                   ...                                                ...
# 183                  NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 184                  NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 185                  NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 186                  NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 187                  NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
#
#                                               imageUrl productGroup category  \
# 0    http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 1    http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 2    http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 3    http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 4    http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# ..                                                 ...          ...      ...
# 183  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 184  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 185  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 186  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 187  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
#
#                     productCategory     productType  \
# 0                  pampers-baby-dry   Maat 2 4/8 kg
# 1                  pampers-baby-dry   Maat 2 4/8 kg
# 2                  pampers-baby-dry   Maat 2 4/8 kg
# 3                  pampers-baby-dry   Maat 2 4/8 kg
# 4                  pampers-baby-dry  Maat 3 6/10 kg
# ..                              ...             ...
# 183  pampers-pure-protection-luiers               4
# 184  pampers-pure-protection-luiers               4
# 185  pampers-pure-protection-luiers               5
# 186  pampers-pure-protection-luiers               5
# 187  pampers-pure-protection-luiers               5
#
#                                      size resourceLanguage Column17  Column18
# 0      33  luiers (voor ongeveer 6 dagen)               ES      NaN       NaN
# 1      42  luiers (voor ongeveer 8 dagen)               ES      NaN       NaN
# 2      46  luiers (voor ongeveer 9 dagen)               ES      NaN       NaN
# 3     58  luiers (voor ongeveer 11 dagen)               ES      NaN       NaN
# 4    100  luiers (voor ongeveer 20 dagen)               ES      NaN       NaN
# ..                                    ...              ...      ...       ...
# 183          28 luiers (voor +/- 6 dagen)               en      NaN       NaN
# 184        160 luiers (voor +/- 32 dagen)               en      NaN       NaN
# 185          24 luiers (voor +/- 6 dagen)               en      NaN       NaN
# 186          30 luiers (voor +/- 4 dagen)               en      NaN       NaN
# 187        132 luiers (voor +/- 26 dagen)               en      NaN       NaN
#
# [188 rows x 18 columns]

# %%
# verify country code are accurate and formated correctly. Returns good and bad df
def country_code_validation(df,ccdf):
    
    dataDict = df.to_dict('records')
    badCountries = []
    
#   send the df columns to lists
    cCodes = ccdf["Code"].tolist()
    cNames = ccdf["Name"].tolist()
    
    
    for index, x in enumerate(dataDict):
        
        country = x["Country"]
        
        CapitalTest = country.isupper()
        
#       Capitalizes names in order to make a match against cNames
        if CapitalTest == False and len(country) > 2:
            country = country.capitalize()
            
#       makes sure country codes are uppercased
        if len(country) == 2:
            x["Country"] = country.upper()
            
            # reassingn country after the switch for later use       
            country = x["Country"]
            
#       change country name to country code if name in CNames   
        if country in cNames:
            nameIndex = cNames.index(country)
            x["Country"] = cCodes[nameIndex]
            
#       Send x to badCountries if not in cCodes and cNames
        elif country not in cCodes:
            badCountries.append(x)
            dataDict.remove(x)
            
    goodDf = pd.DataFrame(dataDict) 
    badDf = pd.DataFrame(badCountries)
   
    return badDf, goodDf

bad, good = country_code_validation(data1, countryCodes)
good
# Out:
#    Country manufacturerName            sku  altSku  \
# 0       AE          Pampers  4015400406907     NaN
# 1       AE          Pampers  4015400406969     NaN
# 2       AE          Pampers  4015400405788     NaN
# 3       AE          Pampers  4015400405887     NaN
# 4       AE          Pampers  4015400406150     NaN
# ..     ...              ...            ...     ...
# 90      AE          Pampers  8001841238586     NaN
# 91      AE          Pampers  8001841238630     NaN
# 92      AE          Pampers  8001841238685     NaN
# 93      AE          Pampers  8001090603326     NaN
# 94      AE          Pampers  8001090603388     NaN
#
#                               model                   productName  \
# 0   AE DIAPERS Pampers new baby-dry  DIAPERS Pampers new baby-dry
# 1   AE DIAPERS Pampers new baby-dry  DIAPERS Pampers new baby-dry
# 2   AE DIAPERS Pampers new baby-dry  DIAPERS Pampers new baby-dry
# 3   AE DIAPERS Pampers new baby-dry  DIAPERS Pampers new baby-dry
# 4       AE DIAPERS Pampers Baby-Dry      DIAPERS Pampers Baby-Dry
# ..                              ...                           ...
# 90       AE Pampers Pure Protection       Pampers Pure Protection
# 91       AE Pampers Pure Protection       Pampers Pure Protection
# 92       AE Pampers Pure Protection       Pampers Pure Protection
# 93       AE Pampers Pure Protection       Pampers Pure Protection
# 94       AE Pampers Pure Protection       Pampers Pure Protection
#
#               upc  releaseDate  \
# 0   4015400406907          NaN
# 1   4015400406969          NaN
# 2   4015400405788          NaN
# 3   4015400405887          NaN
# 4   4015400406150          NaN
# ..            ...          ...
# 90  8001841238586          NaN
# 91  8001841238630          NaN
# 92  8001841238685          NaN
# 93  8001090603326          NaN
# 94  8001090603388          NaN
#
#                                        productPageUrl  \
# 0        https://www.pampers.ae/products/new-baby-dry
# 1        https://www.pampers.ae/products/new-baby-dry
# 2        https://www.pampers.ae/products/new-baby-dry
# 3        https://www.pampers.ae/products/new-baby-dry
# 4    https://www.pampers.ae/products/pampers-baby-dry
# ..                                                ...
# 90  https://www.pampers.ae/diapers-wipes-pure/pamp...
# 91  https://www.pampers.ae/diapers-wipes-pure/pamp...
# 92  https://www.pampers.ae/diapers-wipes-pure/pamp...
# 93  https://www.pampers.ae/diapers-wipes-pure/pamp...
# 94  https://www.pampers.ae/diapers-wipes-pure/pamp...
#
#                                              imageUrl productGroup category  \
# 0   https://azcdn.multibrand.pgsitecore.com/en-AE/...   AE Pampers  Nappies
# 1   https://azcdn.multibrand.pgsitecore.com/en-AE/...   AE Pampers  Nappies
# 2   https://azcdn.multibrand.pgsitecore.com/en-AE/...   AE Pampers  Nappies
# 3   https://azcdn.multibrand.pgsitecore.com/en-AE/...   AE Pampers  Nappies
# 4   https://azcdn.multibrand.pgsitecore.com/en-AE/...   AE Pampers  Nappies
# ..                                                ...          ...      ...
# 90  https://azcdn.multibrand.pgsitecore.com/en-AE/...   AE Pampers  Nappies
# 91  https://azcdn.multibrand.pgsitecore.com/en-AE/...   AE Pampers  Nappies
# 92  https://azcdn.multibrand.pgsitecore.com/en-AE/...   AE Pampers  Nappies
# 93  https://azcdn.multibrand.pgsitecore.com/en-AE/...   AE Pampers    Wipes
# 94  https://azcdn.multibrand.pgsitecore.com/en-AE/...   AE Pampers    Wipes
#
#                     productCategory         productType  \
# 0                      new-baby-dry  Size 1 (2 to 5 kg)
# 1                      new-baby-dry  Size 1 (2 to 5 kg)
# 2                      new-baby-dry  Size 2 (3 to 8 kg)
# 3                      new-baby-dry  Size 2 (3 to 8 kg)
# 4                  pampers-baby-dry  Size 3 (6 to10 kg)
# ..                              ...                 ...
# 90  pampers-pure-protection-diapers              Size 3
# 91  pampers-pure-protection-diapers              Size 4
# 92  pampers-pure-protection-diapers              Size 5
# 93    pampers-pure-protection-wipes                 NaN
# 94    pampers-pure-protection-wipes                 NaN
#
#                              size resourceLanguage
# 0                              21               EN
# 1                              66               EN
# 2                              23               EN
# 3                              64               EN
# 4                              46               EN
# ..                            ...              ...
# 90                     31 nappies               EN
# 91                     28 nappies               EN
# 92                     24 nappies               EN
# 93   1 pack with lid of 48 wipes                EN
# 94  3 packs with lid of 48 wipes                EN
#
# [95 rows x 16 columns]

# %%
# Takes in df and column name. Returns good df with bad dates removed and bad df with errors
def validate_date(df, DateColumnName):
    
    
    dataDict = df.to_dict('records')
    badDate = []
    
#   try to covert x to date. If not send to badDate list
    for x in dataDict:
        try:
            date = x[DateColumnName].date()
            x[DateColumnName] = date
        except:
            badDate.append(x)

#   Remove bad dates from dataDict
    for x in dataDict:
        if x in badDate:
            dataDict.remove(x)
    
    gooddf = pd.DataFrame(dataDict)
    baddf = pd.DataFrame(badDate)
         
    return gooddf, baddf

good, bad = validate_date(data, "releaseDate")
good
# Out:
#    Country manufacturerName            sku                   altSku  \
# 0       nl           Pamper  4015400833079        1 | 420blazit|wow
# 1       NL          Pamperz  8001090268617         1asdf, asdf|pipe
# 2       GE          pampers  4015400833154  this is made of altskus
# 3       US          Pampers  4015400833154       4015400833154, hat
# 4       NL          Pampers  8001090268617           1234, 232, 234
# ..     ...              ...            ...                      ...
# 94      NL          Pampers  8001841023250                      NaN
# 95      NL          Pampers  8001841115917                      NaN
# 96      NL          Pampers  8001090834904                      NaN
# 97      NL          Pampers  8001090834966                      NaN
# 98      NL          Pampers  8001841116037                      NaN
#
#                          model              productName            upc  \
# 0   NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  4015400833079
# 1   NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  8001090088185
# 2   NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  8001090336354
# 3   NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  4015400833154
# 4   NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  4015400833420
# ..                         ...                      ...            ...
# 94  NL Pampers Pure Protection  Pampers Pure Protection  8001841023250
# 95  NL Pampers Pure Protection  Pampers Pure Protection  8001841115917
# 96  NL Pampers Pure Protection  Pampers Pure Protection  8001090834904
# 97  NL Pampers Pure Protection  Pampers Pure Protection  8001090834966
# 98  NL Pampers Pure Protection  Pampers Pure Protection  8001841116037
#
#    releaseDate                                     productPageUrl  \
# 0   2019-07-20  https://www.pampers.nl/producten/pampers-baby-dry
# 1   2019-07-21  https://www.pampers.nl/producten/pampers-baby-dry
# 2   2019-07-22  https://www.pampers.nl/producten/pampers-baby-dry
# 3   2019-07-23  https://www.pampers.nl/producten/pampers-baby-dry
# 4   2019-07-12  https://www.pampers.nl/producten/pampers-baby-dry
# ..         ...                                                ...
# 94         NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 95         NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 96         NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 97         NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 98         NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
#
#                                              imageUrl productGroup category  \
# 0   http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 1   http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 2   http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 3   http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 4   http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# ..                                                ...          ...      ...
# 94  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 95  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 96  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 97  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 98  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
#
#                    productCategory     productType  \
# 0                 pampers-baby-dry   Maat 2 4/8 kg
# 1                 pampers-baby-dry   Maat 2 4/8 kg
# 2                 pampers-baby-dry   Maat 2 4/8 kg
# 3                 pampers-baby-dry   Maat 2 4/8 kg
# 4                 pampers-baby-dry  Maat 3 6/10 kg
# ..                             ...             ...
# 94  pampers-pure-protection-luiers               3
# 95  pampers-pure-protection-luiers               3
# 96  pampers-pure-protection-luiers               4
# 97  pampers-pure-protection-luiers               5
# 98  pampers-pure-protection-luiers               5
#
#                                     size resourceLanguage Column17  Column18
# 0     33  luiers (voor ongeveer 6 dagen)               ES      NaN       NaN
# 1     42  luiers (voor ongeveer 8 dagen)               ES      NaN       NaN
# 2     46  luiers (voor ongeveer 9 dagen)               ES      NaN       NaN
# 3    58  luiers (voor ongeveer 11 dagen)               ES      NaN       NaN
# 4   100  luiers (voor ongeveer 20 dagen)               ES      NaN       NaN
# ..                                   ...              ...      ...       ...
# 94          22 luiers (voor +/- 4 dagen)               en      NaN       NaN
# 95        180 luiers (voor +/- 30 dagen)               en      NaN       NaN
# 96          28 luiers (voor +/- 6 dagen)               en      NaN       NaN
# 97          24 luiers (voor +/- 6 dagen)               en      NaN       NaN
# 98        132 luiers (voor +/- 26 dagen)               en      NaN       NaN
#
# [99 rows x 18 columns]

# %%
# verify country code are accurate and formated correctly. Returns good and bad df
def lang_code_validation(df,ccdf):
    
    dataDict = df.to_dict('records')
    badCountries = []
    
    lCodes = ccdf["639-1"].tolist()
    lNames = ccdf["ISO language name"].tolist()
    
    lCodes = [x.upper() for x in lCodes]
    
    for index, x in enumerate(dataDict):
        
        lang = x["resourceLanguage"]
        
        CapitalTest = lang.isupper()
        
#       Capitalizes names in order to make a match against cNames
        if CapitalTest == False and len(lang) > 2:
            lang = lang.capitalize()
            
#       makes sure country codes are uppercased
        if len(lang) == 2:
            x["resourceLanguage"] = lang.upper()
            
            # reassingn country after the switch for later use       
            lang = x["resourceLanguage"]
            
#       change country name to country code if name in CNames   
        if lang in lNames:
            nameIndex = lNames.index(lang)
            x["resourceLanguage"] = lCodes[nameIndex]
            
#       Send x to badCountries if not in cCodes and cNames
        elif lang not in lCodes:
            badCountries.append(x)
            dataDict.remove(x)
            
    goodDf = pd.DataFrame(dataDict) 
    badDf = pd.DataFrame(badCountries)
   
    return goodDf, badDf

good, bad = lang_code_validation(data1, langCodes)
good
# Out:
#    Country manufacturerName          sku  altSku     model  \
# 0       US            Downy  37000987045     NaN  US Downy
# 1       US            Downy  37000987052     NaN  US Downy
# 2       US            Downy  37000987069     NaN  US Downy
# 3       US            Downy  37000904427     NaN  US Downy
# 4       uS            Downy  37000635222     NaN  US Downy
# 5       US            Downy  37000636373     NaN  US Downy
# 6       US            Downy  37000636373     NaN  US Downy
# 7       uS            Downy  37000636991     NaN  US Downy
# 8       US            Downy  37000637509     NaN  US Downy
# 9       US            Downy  37000357162     NaN  US Downy
# 10     NaN            Downy  37000358046     NaN  US Downy
# 11      US            Downy  37000358305     NaN  US Downy
# 12      uS            Downy  37000106326     NaN  US Downy
# 13      US            Downy  37000295150     NaN  US Downy
# 14      uS            Downy  37000317647     NaN  US Downy
# 15     NaN            Downy  37000353614     NaN  US Downy
# 16      US            Downy  37000902812     NaN  US Downy
# 17      US            Downy  37000903185     NaN  US Downy
# 18      US            Downy  37000903185     NaN  US Downy
#
#                                           productName                    upc  \
# 0   Downy Infusions Amber Blossom In-Wash Scent Bo...                    NaN
# 1   Downy Infusions Amber Blossom In-Wash Scent Bo...                    NaN
# 2   Downy Infusions Amber Blossom In-Wash Scent Bo...  037000987069343434343
# 3   Downy Infusions Amber Blossom In-Wash Scent Bo...                    NaN
# 4   Downy Protect Refresh Active Fresh Liquid Fabr...                    NaN
# 5   Downy Protect Refresh Active Fresh Liquid Fabr...                    NaN
# 6   Downy Protect Refresh Active Fresh Liquid Fabr...                    NaN
# 7   Downy Protect Refresh Active Fresh Liquid Fabr...                    NaN
# 8   Downy Protect Refresh Active Fresh Liquid Fabr...                    NaN
# 9                                          Downy Ball                    NaN
# 10  Ultra Downy Mountain Spring Liquid Fabric Soft...                    NaN
# 11  Ultra Downy Mountain Spring Liquid Fabric Soft...                    NaN
# 12  Ultra Downy Mountain Spring Liquid Fabric Soft...     370001063264342976
# 13  Ultra Downy Mountain Spring Liquid Fabric Soft...                    NaN
# 14  Ultra Downy Mountain Spring Liquid Fabric Soft...                    NaN
# 15  Ultra Downy Mountain Spring Liquid Fabric Soft...                    NaN
# 16  Ultra Downy Infusions Botanical Mist Liquid Fa...                    NaN
# 17  Ultra Downy Infusions Botanical Mist Liquid Fa...                    NaN
# 18  Ultra Downy Infusions Botanical Mist Liquid Fa...                    NaN
#
#     releaseDate                                     productPageUrl  \
# 0           NaN  https://downy.com/en-US/fabric-softener/infusi...
# 1           NaN  https://downy.com/en-US/fabric-softener/infusi...
# 2           NaN  https://downy.com/en-US/fabric-softener/infusi...
# 3           NaN  https://downy.com/en-US/fabric-softener/infusi...
# 4           NaN  https://downy.com/en-US/fabric-softener/protec...
# 5           NaN  https://downy.com/en-US/fabric-softener/protec...
# 6           NaN  https://downy.com/en-US/fabric-softener/protec...
# 7           NaN  https://downy.com/en-US/fabric-softener/protec...
# 8           NaN  https://downy.com/en-US/fabric-softener/protec...
# 9           NaN  https://downy.com/en-US/fabric-softener/DownyBall
# 10          NaN  https://downy.com/en-US/fabric-softener/Ultra-...
# 11          NaN  https://downy.com/en-US/fabric-softener/Ultra-...
# 12          NaN  https://downy.com/en-US/fabric-softener/Ultra-...
# 13          NaN  https://downy.com/en-US/fabric-softener/Ultra-...
# 14          NaN  https://downy.com/en-US/fabric-softener/Ultra-...
# 15          NaN  https://downy.com/en-US/fabric-softener/Ultra-...
# 16          NaN  https://downy.com/en-US/fabric-softener/Downy-...
# 17          NaN  https://downy.com/en-US/fabric-softener/Downy-...
# 18          NaN  https://downy.com/en-US/fabric-softener/Downy-...
#
#                                              imageUrl productGroup  \
# 0                               https://cdn.pioneer.p     US Downy
# 1   https://cdn.pioneer.pgsitecore.commage Title_T...     US Downy
# 2                              https://www.amazon.com     US Downy
# 3                              https://www.amazon.com     US Downy
# 4                              https://www.amazon.com     US Downy
# 5                              https://www.amazon.com     US Downy
# 6                              https://www.amazon.com     US Downy
# 7                              https://www.amazon.com     US Downy
# 8                              https://www.amazon.com     US Downy
# 9                              https://www.amazon.com     US Downy
# 10                             https://www.amazon.com     US Downy
# 11                             https://www.amazon.com     US Downy
# 12                             https://www.amazon.com     US Downy
# 13                             https://www.amazon.com     US Downy
# 14                             https://www.amazon.com     US Downy
# 15                             https://www.amazon.com     US Downy
# 16                             https://www.amazon.com     US Downy
# 17                             https://www.amazon.com     US Downy
# 18                             https://www.amazon.com     US Downy
#
#              category            productCategory        productType  \
# 0         Extra Scent                Scent Beads        Extra Scent
# 1         Extra Scent                Scent Beads        Extra Scent
# 2         Extra Scent                Scent Beads        Extra Scent
# 3         Extra Scent                Scent Beads        Extra Scent
# 4     Odor Prevention  Liquid Fabric Conditioner    Odor Prevention
# 5     odor Prevention  Liquid Fabric Conditioner    Odor Prevention
# 6     Odor Prevention  Liquid Fabric Conditioner    Odor Prevention
# 7     Odor Prevention  Liquid Fabric Conditioner    Odor Prevention
# 8     Odor Prevention  Liquid Fabric Conditioner    Odor Prevention
# 9            Softness                 Downy Ball           Softness
# 10  Fabric Protection  Liquid Fabric Conditioner  Fabric Protection
# 11  Fabric Protection  Liquid Fabric Conditioner  Fabric Protection
# 12  Fabric Protection  Liquid Fabric Conditioner  Fabric Protection
# 13  Fabric Protection  Liquid Fabric Conditioner  Fabric Protection
# 14  Fabric Protection  Liquid Fabric Conditioner  Fabric Protection
# 15  Fabric Protection  Liquid Fabric Conditioner  Fabric Protection
# 16  Fabric Protection  Liquid Fabric Conditioner  Fabric Protection
# 17  Fabric Protection  Liquid Fabric Conditioner  Fabric Protection
# 18  Fabric Protection  Liquid Fabric Conditioner  Fabric Protection
#
#                   Size resourceLanguage  resourceKey
# 0               9.7 oz               EN          NaN
# 1              13.2 oz               EN          NaN
# 2              19.5 oz               EN          NaN
# 3             36.26 oz               EN          NaN
# 4      44 oz, 52 loads               EN          NaN
# 5      67 oz, 78 loads               EN          NaN
# 6      77 oz, 90 loads               EN          NaN
# 7     90 oz, 105 loads               EN          NaN
# 8    103 oz, 120 loads               EN          NaN
# 9           Downy Ball               EN          NaN
# 10    40 Loads, 34 OZ.               EN          NaN
# 11    60 Loads, 51 OZ.               EN          NaN
# 12    90 Loads, 77 OZ.               EN          NaN
# 13   105 Loads, 90 OZ.               EN          NaN
# 14  120 Loads, 103 OZ.               EN          NaN
# 15  150 Loads, 129 OZ.               EN          NaN
# 16    48 Loads, 41 OZ.               EN          NaN
# 17    83 Loads, 77 OZ.               en          NaN
# 18    83 Loads, 77 OZ.               EN          NaN

# %%
# validate product group
def productGroup_validation(df, columnName, brandColumnName):
    
    dataDict = df.to_dict('records')
    
    badPG = []
    
    for x in dataDict:
        pg = x[columnName]
        country = x["Country"]
        brand = x[brandColumnName]
        countryBrand = f"{country} {brand}"
       
        if pg != countryBrand:
            badPG.append(x)
            
    for y in badPG:
        if y in dataDict:
            dataDict.remove(y)
    
    return dataDict, badPG

df2, pgdf = productGroup_validation(data1, "productGroup", "manufacturerName")
pgdf
# Out:
# []

# %%
def leading_zeros(df,skuColumnName):
    
#   declared here so that when the function is not triggered the original df is returned
    lzDf = df
    
    dataDict = df.to_dict('records')
    
#   grab total number of rows
    skuCount = len(dataDict)
    
#   set threshold to trigger function
    triggerThreshold = skuCount * 0.60
    
    counter = 0

#   count num of skus with leading zeros
    for x in dataDict:
        
        sku = x[skuColumnName]
        
        skuLen = len(sku) - len(sku.lstrip('0'))
        
        if skuLen != 0:
            counter +=1
            
#   trigger function if counter exceeds thresh       
    if counter > triggerThreshold:
        
    #   get len counts
        lenCounts = df[skuColumnName].apply(len).value_counts()

    #   grab max count for len
        avLenMax = lenCounts.values.max()

    #   grab key for max count. This will be the actual len
        for key, value in lenCounts.items():
            if value == avLenMax:
                actualSkuLen = key

    #   add zeros to skus up to actualSkuLen. commentted out since this alters the df directly
#         lzdf[skuColumnName]= list(map(lambda x: x.zfill(actualSkuLen), lzdf[skuColumnName]))

    #   adds zeros to skus up to acutalSkuLen   
        for x in dataDict:
            sku = x[skuColumnName]
            sku = sku.zfill(actualSkuLen)
            x[skuColumnName] = sku
            
        lzDf = pd.DataFrame(dataDict)
        
    else:
        pass
    
    
    return lzDf

df1 = leading_zeros(data, "SKU")
df1
# Out:
#      Country brandName             SKU altSku           model  \
# 0         US     KRAFT  00021000010615    NaN  US Kraft Heinz
# 1         US     KRAFT  00021000014088    NaN  US Kraft Heinz
# 2         US     KRAFT  00021000018567    NaN  US Kraft Heinz
# 3         US     KRAFT  00021000018635    NaN  US Kraft Heinz
# 4         US     KRAFT  00021000028207    NaN  US Kraft Heinz
# ...      ...       ...             ...    ...             ...
# 2356      US     HEINZ  00013000001700    NaN  US Kraft Heinz
# 2357      US     HEINZ  00013000002851    NaN  US Kraft Heinz
# 2358      US     HEINZ  00013000012409    NaN  US Kraft Heinz
# 2359      US     HEINZ  00013000000833    NaN  US Kraft Heinz
# 2360      US     HEINZ  00013000000840    NaN  US Kraft Heinz
#
#                                             productName  upc  releaseDate  \
# 0     Kraft 100% Grated Parmesan Cheese Shaker 24 oz...  NaN          NaN
# 1           Kraft Asian Sesame Dressing 16 fl oz Bottle  NaN          NaN
# 2     Kraft Big Slice Mild Cheddar Natural Cheese Sl...  NaN          NaN
# 3     Kraft Big Slice Sharp Cheddar Natural Cheese S...  NaN          NaN
# 4          Kraft Honey Mustard Dressing 16 fl oz Bottle  NaN          NaN
# ...                                                 ...  ...          ...
# 2356            Heinz Zesty Cocktail Sauce 12 oz Bottle  NaN          NaN
# 2357             Heinz Worcestershire Sauce 5 oz Bottle  NaN          NaN
# 2358          Heinz Mayochup Saucy Sauce 16.5 oz Bottle  NaN          NaN
# 2359           Heinz Mayocue Saucy Sauce 16.7 oz Bottle  NaN          NaN
# 2360          Heinz Mayomust Saucy Sauce 16.6 oz Bottle  NaN          NaN
#
#       productPageUrl                                           imageURL  \
# 0                NaN  http://images.salsify.com/image/upload/s--RlgA...
# 1                NaN  http://images.salsify.com/image/upload/s--6NCy...
# 2                NaN  http://images.salsify.com/image/upload/s--Ish-...
# 3                NaN  http://images.salsify.com/image/upload/s--pQ2S...
# 4                NaN  http://images.salsify.com/image/upload/s--z5lM...
# ...              ...                                                ...
# 2356             NaN                                                NaN
# 2357             NaN                                                NaN
# 2358             NaN                                                NaN
# 2359             NaN                                                NaN
# 2360             NaN                                                NaN
#
#         productGroup                              category        foodType  \
# 0     US Kraft Heinz                        Cheese & Dairy          Cheese
# 1     US Kraft Heinz  Sauces, Condiments & Salad Dressings  Salad Dressing
# 2     US Kraft Heinz                        Cheese & Dairy          Cheese
# 3     US Kraft Heinz                        Cheese & Dairy          Cheese
# 4     US Kraft Heinz  Sauces, Condiments & Salad Dressings  Salad Dressing
# ...              ...                                   ...             ...
# 2356  US Kraft Heinz  Sauces, Condiments & Salad Dressings          Sauces
# 2357  US Kraft Heinz  Sauces, Condiments & Salad Dressings          Sauces
# 2358  US Kraft Heinz  Sauces, Condiments & Salad Dressings      Condiments
# 2359  US Kraft Heinz  Sauces, Condiments & Salad Dressings      Condiments
# 2360  US Kraft Heinz  Sauces, Condiments & Salad Dressings      Condiments
#
#       brand                                        productType packageSize  \
# 0     KRAFT                             PARMESAN CHEESE SHAKER        24.0
# 1     KRAFT                              ASIAN SESAME DRESSING        16.0
# 2     KRAFT                             MILD CHEDDAR BIG SLICE         8.0
# 3     KRAFT                            SHARP CHEDDAR BIG SLICE         8.0
# 4     KRAFT                             HONEY MUSTARD DRESSING        16.0
# ...     ...                                                ...         ...
# 2356  HEINZ  Specialty Sauces - Zesty Cocktail Sauce 12 oz ...          12
# 2357  HEINZ  Specialty Sauces - Worcestershire Sauce 5 oz B...           5
# 2358  HEINZ           Flavor Mashups - Mayochup 16.5 oz Bottle        16.5
# 2359  HEINZ            Flavor Mashups - Mayocue 16.7 oz Bottle        16.7
# 2360  HEINZ           Flavor Mashups - Mayomust 16.6 oz Bottle        16.6
#
#      Unnamed: 16
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2356         NaN
# 2357         NaN
# 2358         NaN
# 2359         NaN
# 2360         NaN
#
# [2361 rows x 17 columns]

# %%
# takes in df and column name. Coverts neg ints to positive. Returns corrected df.
def neg_num_check(df, columnName):
    
    dataDict = df.to_dict('records')
    
    for x in dataDict:
        try:
            num = int(x[columnName])
        except:
            pass
        if num < 0:
            x[columnName] = abs(num)
    
    correctedDf = pd.DataFrame(dataDict)
    
    return correctedDf


neg_num_check(data, "sku")
# Out:
#     Country manufacturerName            sku                   altSku  \
# 0        nl           Pamper  4015400833079        1 | 420blazit|wow
# 1        NL          Pamperz  8001090268617         1asdf, asdf|pipe
# 2        GE          pampers  4015400833154  this is made of altskus
# 3        US          Pampers  4015400833154       4015400833154, hat
# 4        NL          Pampers  8001090268617           1234, 232, 234
# ..      ...              ...            ...                      ...
# 183      NL          Pampers  8001090834904                      NaN
# 184      NL          Pampers  8001841115979                      NaN
# 185      NL          Pampers  8001090834966                      NaN
# 186      NL          Pampers  8001841023335                      NaN
# 187      NL          Pampers  8001841116037                      NaN
#
#                           model              productName            upc  \
# 0    NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  4015400833079
# 1    NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  8001090088185
# 2    NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  8001090336354
# 3    NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  4015400833154
# 4    NL LUIERS Pampers Baby-Dry  LUIERS Pampers Baby-Dry  4015400833420
# ..                          ...                      ...            ...
# 183  NL Pampers Pure Protection  Pampers Pure Protection  8001090834904
# 184  NL Pampers Pure Protection  Pampers Pure Protection  8001841115979
# 185  NL Pampers Pure Protection  Pampers Pure Protection  8001090834966
# 186  NL Pampers Pure Protection  Pampers Pure Protection  8001841023335
# 187  NL Pampers Pure Protection  Pampers Pure Protection  8001841116037
#
#              releaseDate                                     productPageUrl  \
# 0    2019-07-20 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# 1    2019-07-21 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# 2    2019-07-22 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# 3    2019-07-23 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# 4    2019-07-12 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# ..                   ...                                                ...
# 183                  NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 184                  NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 185                  NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 186                  NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
# 187                  NaN  https://www.pampers.nl/luiers-babydoekjes-pure...
#
#                                               imageUrl productGroup category  \
# 0    http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 1    http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 2    http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 3    http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 4    http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# ..                                                 ...          ...      ...
# 183  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 184  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 185  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 186  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 187  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
#
#                     productCategory     productType  \
# 0                  pampers-baby-dry   Maat 2 4/8 kg
# 1                  pampers-baby-dry   Maat 2 4/8 kg
# 2                  pampers-baby-dry   Maat 2 4/8 kg
# 3                  pampers-baby-dry   Maat 2 4/8 kg
# 4                  pampers-baby-dry  Maat 3 6/10 kg
# ..                              ...             ...
# 183  pampers-pure-protection-luiers               4
# 184  pampers-pure-protection-luiers               4
# 185  pampers-pure-protection-luiers               5
# 186  pampers-pure-protection-luiers               5
# 187  pampers-pure-protection-luiers               5
#
#                                      size resourceLanguage Column17  Column18
# 0      33  luiers (voor ongeveer 6 dagen)               ES      NaN       NaN
# 1      42  luiers (voor ongeveer 8 dagen)               ES      NaN       NaN
# 2      46  luiers (voor ongeveer 9 dagen)               ES      NaN       NaN
# 3     58  luiers (voor ongeveer 11 dagen)               ES      NaN       NaN
# 4    100  luiers (voor ongeveer 20 dagen)               ES      NaN       NaN
# ..                                    ...              ...      ...       ...
# 183          28 luiers (voor +/- 6 dagen)               en      NaN       NaN
# 184        160 luiers (voor +/- 32 dagen)               en      NaN       NaN
# 185          24 luiers (voor +/- 6 dagen)               en      NaN       NaN
# 186          30 luiers (voor +/- 4 dagen)               en      NaN       NaN
# 187        132 luiers (voor +/- 26 dagen)               en      NaN       NaN
#
# [188 rows x 18 columns]

# %%
def selector_validation(df, selectorColumnNameList):
    
    for x in selectorList:
        a = outlier_detect(df,x)
#         print(a)
    
    return a

selectorList = ["size"]
b, c =  selector_validation(data,selectorList)
c
# Out:
#     Country manufacturerName            sku altSku  \
# 58       NL          Pampers  8001090298300    NaN
# 113      NL          Pampers  8001841072371    NaN
# 10       NL          Pampers  8001090336408    NaN
# 100      NL          Pampers  8001090706485    NaN
# 126      NL          Pampers  4015400622253    NaN
# ..      ...              ...            ...    ...
# 97       NL          Pampers  8001090288011    NaN
# 34       NL          Pampers  4015400566786    NaN
# 133      NL          Pampers  4015400696377    NaN
# 45       NL          Pampers  4015400834489    NaN
# 145      NL          Pampers  4015400696438    NaN
#
#                                                model  \
# 58                        NL LUIERS Pampers Baby-Dry
# 113          NL LUIERBROEKJES Pampers Baby-Dry Pants
# 10                        NL LUIERS Pampers Baby-Dry
# 100          NL LUIERBROEKJES Pampers Baby-Dry Pants
# 126         NL DOEKJES Pampers Sensitive Babydoekjes
# ..                                               ...
# 97              NL LUIERS Pampers Premium Protection
# 34                        NL LUIERS Pampers Baby-Dry
# 133  NL LUIERS Pampers Premium Protection Active Fit
# 45                        NL LUIERS Pampers Baby-Dry
# 145  NL LUIERS Pampers Premium Protection Active Fit
#
#                                       productName            upc  \
# 58                        LUIERS Pampers Baby-Dry  8001090298300
# 113          LUIERBROEKJES Pampers Baby-Dry Pants  8001841072371
# 10                        LUIERS Pampers Baby-Dry  8001090336408
# 100          LUIERBROEKJES Pampers Baby-Dry Pants  8001090706485
# 126         DOEKJES Pampers Sensitive Babydoekjes  4015400622253
# ..                                            ...            ...
# 97              LUIERS Pampers Premium Protection  8001090288011
# 34                        LUIERS Pampers Baby-Dry  4015400566786
# 133  LUIERS Pampers Premium Protection Active Fit  4015400696377
# 45                        LUIERS Pampers Baby-Dry  4015400834489
# 145  LUIERS Pampers Premium Protection Active Fit  4015400696438
#
#              releaseDate                                     productPageUrl  \
# 58                   NaN  https://www.pampers.nl/producten/pampers-baby-dry
# 113                  NaN  https://www.pampers.nl/producten/pampers-baby-...
# 10   2019-07-08 00:00:00  https://www.pampers.nl/producten/pampers-baby-dry
# 100                  NaN  https://www.pampers.nl/producten/pampers-baby-...
# 126                  NaN  https://www.pampers.nl/producten/pampers-sensi...
# ..                   ...                                                ...
# 97                   NaN  https://www.pampers.nl/producten/pampers-premi...
# 34                   NaN  https://www.pampers.nl/producten/pampers-baby-dry
# 133                  NaN  https://www.pampers.nl/producten/pampers-premi...
# 45                   NaN  https://www.pampers.nl/producten/pampers-baby-dry
# 145                  NaN  https://www.pampers.nl/producten/pampers-premi...
#
#                                               imageUrl productGroup category  \
# 58   http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 113  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 10   http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 100  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 126  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers  Doekjes
# ..                                                 ...          ...      ...
# 97   http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 34   http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers      Yup
# 133  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 45   http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
# 145  http://azcdn.multibrand.pgsitecore.com/nl-NL/-...   NL Pampers   Luiers
#
#                            productCategory       productType  \
# 58                        pampers-baby-dry     Maat 7 15+ kg
# 113                 pampers-baby-dry-pants   Maat 5 12/17 kg
# 10                        pampers-baby-dry    Maat 3 6/10 kg
# 100                 pampers-baby-dry-pants    Maat 3 6/11 kg
# 126          pampers-sensitive-babydoekjes               NaN
# ..                                     ...               ...
# 97              pampers-premium-protection     Maat 6 13+ kg
# 34                        pampers-baby-dry   Maat 5 11/16 kg
# 133  pampers-premium-protection-active-fit    Maat 4 8/16 kg
# 45                        pampers-baby-dry  Maat 5+ 12/17 kg
# 145  pampers-premium-protection-active-fit   Maat 5 11/23 kg
#
#                                             size resourceLanguage Column17  \
# 58            17  luiers (voor ongeveer 4 dagen)               ES      NaN
# 113  144  luierbroekjes (voor ongeveer 36 dagen)               ES      NaN
# 10            38  luiers (voor ongeveer 8 dagen)               ES      NaN
# 100   80  luierbroekjes (voor ongeveer 18 dagen)               ES      NaN
# 126                                 504  doekjes               ES      NaN
# ..                                           ...              ...      ...
# 97           120 luiers (voor ongeveer 30 dagen)               ES      NaN
# 34          144  luiers (voor ongeveer 36 dagen)               ES      NaN
# 133          64  luiers (voor ongeveer 15 dagen)               ES      NaN
# 45            35  luiers (voor ongeveer 9 dagen)               ES      NaN
# 145          60  luiers (voor ongeveer 15 dagen)               ES      NaN
#
#      Column18
# 58        NaN
# 113       NaN
# 10        NaN
# 100       NaN
# 126       NaN
# ..        ...
# 97        NaN
# 34        NaN
# 133       NaN
# 45        NaN
# 145       NaN
#
# [157 rows x 18 columns]

# %%
# simiplier solution found. Not using.
# Returns True for store feeds false for product feeds
def isStoreFeed(df):
    
    isStoreFeed = False
    
    columnNames = df.columns.tolist()
    
    r = re.compile(".*store[^'+]|.*seller[^'+]")
    
    matchedList = list(filter(r.match, columnNames))
    
    if len(matchedList) >= 3:
        isStoreFeed = True
    
    return isStoreFeed

isStoreFeed(sfData)
# Out:
# True

# %%
# removes lat and long outside the actual bounds
def latLongValidation(df,latColumn,longColumn):
    
    lat = df[latColumn]
    long = df[longColumn]
    
    lat = map(float, lat)
    long = map(float, long)
    
    badLat = []
    badLong = []
    
    [badLat.append(ind) for ind,x in enumerate(lat) if x >= 90 or x <= -90 ]
    [badLong.append(ind) for ind,x in enumerate(long) if x >= 180 or x <= -180 ]
    
    badLatLong = list(set(badLat + badLong))
    
    cleanDf = df.drop(badLatLong)
    badDf = df.iloc[badLatLong]
    
    return cleanDf,badDf

latLongValidation(sfData,"latitude","longitude")
# Out:
# (     Country         sellerName sellerID                     storeName  \
#  0         CA  Acklands Grainger   100000  Acklands Grainger Inc - AC0
#  1         CA  Acklands Grainger   100000  Acklands Grainger Inc - AA9
#  2         CA  Acklands Grainger   100000  Acklands Grainger Inc - AC4
#  3         CA  Acklands Grainger   100000  Acklands Grainger Inc - AC1
#  4         CA  Acklands Grainger   100000  Acklands Grainger Inc - AC2
#  ...      ...                ...      ...                           ...
#  8657      US          White Cap   110600      White Cap - Seattle - 46
#  8658      US          White Cap   110600      White Cap - Spokane - 47
#  8659      US          White Cap   110600      White Cap - Tacoma - 506
#  8660      US          White Cap   110600    White Cap - Cheyenne - 501
#  8661      US      Wylaco Supply   110700            Wylaco Supply - 00
#
#               storeID                            productGroup  sku  \
#  0               AC0                 US GearWrench | US Jobox  NaN
#  1               AA9                 US GearWrench | US Jobox  NaN
#  2               AC4                 US GearWrench | US Jobox  NaN
#  3               AC1                 US GearWrench | US Jobox  NaN
#  4               AC2                 US GearWrench | US Jobox  NaN
#  ...              ...                                     ...  ...
#  8657    Seattle - 47  US Crescent | US GearWrench | US Jobox  NaN
#  8658    Spokane - 48  US Crescent | US GearWrench | US Jobox  NaN
#  8659    Tacoma - 507  US Crescent | US GearWrench | US Jobox  NaN
#  8660  Cheyenne - 502  US Crescent | US GearWrench | US Jobox  NaN
#  8661              00             US Crescent | US GearWrench  NaN
#
#                        address  address2        city  ...        Wednesday  \
#  0              3 Kingsview Rd       NaN     Airdrie  ...  8:00am - 5:00pm
#  1               5802 - 50 Ave       NaN  Bonnyville  ...  7:00am - 5:00pm
#  2     3401 - 19 St NE Bay #10       NaN     Calgary  ...  7:00am - 5:00pm
#  3        4340 Manhattan Rd SE       NaN     Calgary  ...  7:00am - 5:00pm
#  4            4949 - 61 Ave SE       NaN     Calgary  ...  7:00am - 5:00pm
#  ...                       ...       ...         ...  ...              ...
#  8657        4121 - 6th Ave NW       NaN     Seattle  ...  7:00am - 4:30pm
#  8658         3825 E Trent Ave       NaN     Spokane  ...  7:00am - 4:30pm
#  8659           3037 Center St       NaN      Tacoma  ...  7:00am - 4:30pm
#  8660            3957 W 5th St       NaN    Cheyenne  ...  7:00am - 4:30pm
#  8661           315 Vallejo St       NaN      Denver  ...  7:30am - 5:00pm
#
#               Thursday           Friday          Saturday  Sunday   latitude  \
#  0     8:00am - 5:00pm  8:00am - 5:00pm               NaN     NaN  51.083163
#  1     7:00am - 5:00pm  7:00am - 5:00pm               NaN     NaN  55.278487
#  2     7:00am - 5:00pm  7:00am - 5:00pm               NaN     NaN  42.931627
#  3     7:00am - 5:00pm  7:00am - 5:00pm               NaN     NaN  51.014805
#  4     7:00am - 5:00pm  7:00am - 5:00pm               NaN     NaN  50.998624
#  ...               ...              ...               ...     ...        ...
#  8657  7:00am - 4:30pm  7:00am - 4:30pm            Closed  Closed  47.657372
#  8658  7:00am - 4:30pm  7:00am - 4:30pm            Closed  Closed  32.277534
#  8659  7:00am - 4:30pm  7:00am - 4:30pm            Closed  Closed  41.220287
#  8660  7:00am - 4:30pm  7:00am - 4:30pm            Closed  Closed  41.116547
#  8661  7:30am - 5:00pm  7:30am - 5:00pm  8:00am - 12:00pm  closed  39.698343
#
#       longitude                                 sellerUrl sellerUrlLabel  \
#  0     -114.012                                       NaN            NaN
#  1     -114.773                                       NaN            NaN
#  2     -81.2125                                       NaN            NaN
#  3     -114.052                                       NaN            NaN
#  4     -113.963                                       NaN            NaN
#  ...        ...                                       ...            ...
#  8657  -122.364  https://www.whitecap.com/shop/en/wc/home    See Website
#  8658  -111.019  https://www.whitecap.com/shop/en/wc/home    See Website
#  8659  -112.023  https://www.whitecap.com/shop/en/wc/home    See Website
#  8660  -104.848  https://www.whitecap.com/shop/en/wc/home    See Website
#  8661  -105.003                   https://www.wylaco.com/    See Website
#
#       miscText
#  0         NaN
#  1         NaN
#  2         NaN
#  3         NaN
#  4         NaN
#  ...       ...
#  8657      NaN
#  8658      NaN
#  8659      NaN
#  8660      NaN
#  8661      NaN
#
#  [8662 rows x 25 columns], Empty DataFrame
#  Columns: [Country, sellerName, sellerID, storeName, storeID, productGroup, sku, address, address2, city, state, zip, phone, Monday, Tuesday, Wednesday, Thursday, Friday, Saturday, Sunday, latitude, longitude, sellerUrl, sellerUrlLabel, miscText]
#  Index: []
#
#  [0 rows x 25 columns])
